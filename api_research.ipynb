# %% [markdown]
# # API Research & Testing Notebook
#
# Use this notebook to research and test new tools for the API.
# Updated to use the INI Multi-App configuration architecture.

# %%
import sys
import os

# Add pykite root to path so we can import local modules from the deploy folder
root_dir = os.path.dirname(os.getcwd())
if root_dir not in sys.path:
    sys.path.append(root_dir)
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())

import load_kite_from_access
print("Modules imported successfully!")
# Out:
# Modules imported successfully!

# %%
# Define which app you are testing
APP_NAME = 'algotestlive'

# Fetch the session using the new INI Factory Method
kite = load_kite_from_access.get_kite_session(APP_NAME)

if kite:
    print("\n--- Session Ready! ---")
    print(f"Logged in as: {kite.profile()['user_name']}")
else:
    print(f"❌ Could not fetch session for {APP_NAME}.")
    print(f"Run `python deploy/get_token_local.py {APP_NAME}` in your terminal to login first.")
# Out:
# ✅ [algotestlive] Connected: J Sathiyavani (ID: VTE508)
#
# --- Session Ready! ---
# Logged in as: J Sathiyavani

# %%
def get_orders(kite):
    """Fetch and print orders."""
    try:
        orders = kite.orders()
        print(f"Fetched {len(orders)} orders.")
        return orders
    except Exception as e:
        print(f"Error fetching orders: {e}")
        return None

def get_holdings(kite):
    """Fetch and print holdings."""
    try:
        holdings = kite.holdings()
        print(f"Fetched {len(holdings)} holdings.")
        return holdings
    except Exception as e:
        print(f"Error fetching holdings: {e}")
        return None

def get_positions(kite):
    """Fetch and print positions."""
    try:
        positions = kite.positions()
        print(f"Fetched positions: {positions.keys()}")
        return positions
    except Exception as e:
        print(f"Error fetching positions: {e}")
        return None

def place_stop_loss_gtt(kite, tradingsymbol, exchange, trigger_percent, quantity=1, product=None):
    """
    Places a GTT Stop Loss order.
    
    Args:
        kite: KiteConnect instance
        tradingsymbol: Trading symbol (e.g., 'INFY', 'CRUDEOIL23OCTFUT')
        exchange: Exchange (e.g., 'NSE', 'MCX')
        trigger_percent: Percentage to drop (e.g., 5 for 5% SL). ENTER POSITIVE NUMBER.
        quantity: Quantity to sell
        product: Order product (default is CNC/NRML based on segment, but best to specify)
    """
    try:
        # 1. Fetch LTP to calculate trigger price
        instrument_key = f"{exchange}:{tradingsymbol}"
        ltp_data = kite.ltp(instrument_key)
        
        if not ltp_data or instrument_key not in ltp_data:
            print(f"❌ Error: Could not fetch LTP for {instrument_key}")
            return None
            
        last_price = ltp_data[instrument_key]['last_price']
        print(f"Current LTP for {tradingsymbol}: {last_price}")
        
        # 2. Calculate Trigger Price
        # For Sell SL, trigger is BELOW LTP
        # Example: LTP 100, 5% SL -> Trigger at 95
        # --- PROACTIVE GTT MINIMUM GAP VALIDATION ---
        # Kite strictly enforces a > 0.25% gap between LTP and Trigger.
        if abs(trigger_percent) <= 0.25:
            suggested_percent = 0.26 if trigger_percent >= 0 else -0.26
            print(f"⚠️ Warning: {trigger_percent}% is too close to LTP. Kite requires >0.25% gap.")
            print(f"🔄 Auto-adjusting trigger_percent from {trigger_percent}% to {suggested_percent}%")
            trigger_percent = suggested_percent

        trigger_price = last_price * (1 - (trigger_percent / 100))
        trigger_price = round(trigger_price * 20) / 20  # Round to nearest tick (0.05)
        
        print(f"Calculated SL Trigger Price ({trigger_percent}% drop): {trigger_price}")
        
        # 3. Place GTT
        trigger_type = kite.GTT_TYPE_SINGLE
        
        if not product:
             product = kite.PRODUCT_CNC if exchange == 'NSE' else kite.PRODUCT_NRML

        # Order to be placed when triggered
        orders = [
            {
                "exchange": exchange,
                "tradingsymbol": tradingsymbol,
                "transaction_type": kite.TRANSACTION_TYPE_SELL,
                "quantity": quantity,
                "order_type": kite.ORDER_TYPE_LIMIT,
                "product": product,
                "price": trigger_price, 
            }
        ]
        
        # Place GTT
        gtt_id = kite.place_gtt(
            trigger_type=trigger_type,
            tradingsymbol=tradingsymbol,
            exchange=exchange,
            trigger_values=[trigger_price],
            last_price=last_price,
            orders=orders
        )
        
        print(f"✅ GTT Order Placed. ID: {gtt_id}")
        return gtt_id
        
    except Exception as e:
        print(f"❌ Error placing GTT: {e}")
        return None

def place_market_order(kite, tradingsymbol, exchange, transaction_type, quantity, product=None):
    """Places a Market order."""
    try:
        if not product:
            product = kite.PRODUCT_CNC if exchange == 'NSE' else kite.PRODUCT_NRML
        
        order_id = kite.place_order(
            variety=kite.VARIETY_REGULAR,
            exchange=exchange,
            tradingsymbol=tradingsymbol,
            transaction_type=transaction_type,
            quantity=quantity,
            product=product,
            order_type=kite.ORDER_TYPE_MARKET
        )
        print(f"✅ Market Order placed. ID: {order_id}")
        return order_id
    except Exception as e:
        print(f"❌ Error placing market order: {e}")
        return None

def place_limit_order(kite, tradingsymbol, exchange, transaction_type, quantity, price, product=None):
    """Places a Limit order."""
    try:
        if not product:
            product = kite.PRODUCT_CNC if exchange == 'NSE' else kite.PRODUCT_NRML
            
        order_id = kite.place_order(
            variety=kite.VARIETY_REGULAR,
            exchange=exchange,
            tradingsymbol=tradingsymbol,
            transaction_type=transaction_type,
            quantity=quantity,
            product=product,
            order_type=kite.ORDER_TYPE_LIMIT,
            price=price
        )
        print(f"✅ Limit Order placed. ID: {order_id}")
        return order_id
    except Exception as e:
        print(f"❌ Error placing limit order: {e}")
        return None

def create_alert(kite, name, instrument_token, operator='>=', trigger_price=0.0):
    """
    Creates a simple price alert using the Kite Alerts API.
    operator can be: '>=', '<=', '==', etc.
    """
    try:
        import requests
        
        headers = {
            "X-Kite-Version": "3",
            "Authorization": f"token {kite.api_key}:{kite.access_token}"
        }
        
        # Kite Alerts API format
        payload = [{
            "name": name,
            "instrument_token": str(instrument_token), # usually tracking token
            "condition": {
                "operator": operator,
                "trigger_value": float(trigger_price),
                "data_point": "last_price"
            }
        }]
        
        url = "https://api.kite.trade/alerts"
        
        # If pykiteconnect has a native method, use it
        if hasattr(kite, 'add_alert'):
            response = kite.add_alert(payload)
        else:
            response = requests.post(url, headers=headers, json=payload).json()
            
        print(f"✅ Alert created: {response}")
        return response
    except Exception as e:
        print(f"❌ Error creating alert: {e}")
        return None

# %%
import json
import os
import time

class PriceMonitor:
    """
    Background service to fetch prices for a list of tracked symbols.
    Stores latest prices in a dictionary.
    """
    def __init__(self, kite):
        self.kite = kite
        self.watchlist = set() # Set of 'exchange:symbol' strings
        self.latest_prices = {} # Dict: {'exchange:symbol': price}

    def add_symbol(self, exchange, symbol):
        """Add a symbol to the watchlist."""
        key = f"{exchange}:{symbol}"
        self.watchlist.add(key)
        print(f"Start tracking: {key}")

    def remove_symbol(self, exchange, symbol):
        """Remove a symbol from the watchlist."""
        key = f"{exchange}:{symbol}"
        if key in self.watchlist:
            self.watchlist.remove(key)
            if key in self.latest_prices:
                del self.latest_prices[key]
            print(f"Stop tracking: {key}")

    def update_prices(self):
        """Fetch fresh prices for all symbols in watchlist."""
        if not self.watchlist:
            return
            
        try:
            # Bulk fetch
            # print(f"Fetching prices for {len(self.watchlist)} symbols...")
            ltp_data = self.kite.ltp(list(self.watchlist))
            
            for key, data in ltp_data.items():
                self.latest_prices[key] = data['last_price']
                
            # print(f"Prices updated at {time.strftime('%H:%M:%S')}")
        except Exception as e:
            print(f"❌ Error updating prices: {e}")

    def get_price(self, exchange, symbol):
        """Get the latest fetched price safely."""
        key = f"{exchange}:{symbol}"
        return self.latest_prices.get(key)


class TrailingStopLossManager:
    """
    Manages Trailing Stop Loss using GTT orders and a local JSON disk cache.
    Tracks the Highest Point (High Water Mark - HWM) of the LTP.
    Consumer of PriceMonitor data.
    """
    def __init__(self, kite, cache_file="tsl_cache.json"):
        self.kite = kite
        self.cache_file = cache_file
        self.cache = self.load_cache()

    def load_cache(self):
        """Load HWM data from disk."""
        if os.path.exists(self.cache_file):
            try:
                with open(self.cache_file, 'r') as f:
                    return json.load(f)
            except Exception as e:
                print(f"Error loading cache: {e}")
                return {}
        return {}

    def save_cache(self):
        """Save HWM data to disk."""
        try:
            with open(self.cache_file, 'w') as f:
                json.dump(self.cache, f, indent=4)
        except Exception as e:
            print(f"Error saving cache: {e}")

    def update_trailing_stop_loss(self, tradingsymbol, exchange, trailing_percent, quantity=1, product=None, gtt_id=None, current_ltp=None):
        """
        Updates the Trailing Stop Loss for a given symbol.
        Requires `current_ltp` to be passed (e.g. from PriceMonitor).
        """
        instrument_key = f"{exchange}:{tradingsymbol}"
        
        # Validate incoming price
        if current_ltp is None:
            # Fallback: fetch manually if needed, but warn
            print(f"⚠️ Warning: No price provided for {tradingsymbol}, fetching manually.")
            ltp_data = self.kite.ltp(instrument_key)
            if instrument_key in ltp_data:
                current_ltp = ltp_data[instrument_key]['last_price']
            else:
                print(f"❌ Failed to fetch price for {tradingsymbol}")
                return

        # 2. Get or Initialize Cache Entry
        if instrument_key not in self.cache:
            print(f"Creating new TSL entry for {tradingsymbol} at LTP {current_ltp}")
            self.cache[instrument_key] = {
                "hwm_price": current_ltp,
                "gtt_id": gtt_id, # Can be None initially if not provided
                "last_trigger_price": 0,
                "symbol": tradingsymbol,
                "exchange": exchange
            }
        
        entry = self.cache[instrument_key]
        
        # Update HWM if current price is higher
        if current_ltp > entry["hwm_price"]:
            # print(f"🚀 New High for {tradingsymbol}! Old HWM: {entry['hwm_price']} -> New HWM: {current_ltp}")
            entry["hwm_price"] = current_ltp
            self.save_cache() # Save immediately
            
        hwm_price = entry["hwm_price"]
        
        # 3. Calculate New SL Price
        new_sl_price = hwm_price * (1 - (trailing_percent / 100))
        new_sl_price = round(new_sl_price * 20) / 20 # Round to tick
        
        current_trigger_price = entry.get("last_trigger_price", 0)
        
        # 4. Check if we need to modify GTT
        if new_sl_price > current_trigger_price:
            print(f"⚡ Trailing Up {tradingsymbol}! HWM: {hwm_price}, New SL: {new_sl_price} (Old: {current_trigger_price})")
            
            active_gtt_id = entry.get("gtt_id") or gtt_id
            
            if not active_gtt_id:
                # Place NEW GTT
                print("Placing Initial GTT...")
                # Note: this relies on place_stop_loss_gtt existing globally in the notebook!
                new_gtt_id = place_stop_loss_gtt(
                    self.kite, tradingsymbol, exchange, trailing_percent, quantity=quantity, product=product
                )
                if new_gtt_id:
                    entry["gtt_id"] = new_gtt_id
                    entry["last_trigger_price"] = new_sl_price
                    self.save_cache()
            else:
                # MODIFY Existing GTT
                try:
                    self.kite.modify_gtt(
                        trigger_id=active_gtt_id,
                        trigger_type=self.kite.GTT_TYPE_SINGLE,
                        tradingsymbol=tradingsymbol,
                        exchange=exchange,
                        trigger_values=[new_sl_price],
                        last_price=current_ltp,
                        orders=[{
                            "exchange": exchange,
                            "tradingsymbol": tradingsymbol,
                            "transaction_type": self.kite.TRANSACTION_TYPE_SELL,
                            "quantity": quantity,
                            "order_type": self.kite.ORDER_TYPE_LIMIT,
                            "product": product if product else self.kite.PRODUCT_CNC,
                            "price": new_sl_price
                        }]
                    )
                    print(f"✅ Modified GTT {active_gtt_id} to Trigger: {new_sl_price}")
                    entry["last_trigger_price"] = new_sl_price
                    self.save_cache()
                except Exception as e:
                    print(f"❌ Error modifying GTT {active_gtt_id}: {e}")
                    if "InputException" in str(e) or "not found" in str(e).lower():
                        print("GTT ID invalid, clearing from cache.")
                        entry["gtt_id"] = None
                        self.save_cache()

# %%
# --- Comprehensive Test for algotestlive ---
print("=====================================")
print("🧪 Testing Full Suite on algotestlive")
print("=====================================")

tradingsymbol = "GOLDM26APRFUT"
exchange = "MCX"
quantity = 1  # 1 lot

if 'kite' in locals() and kite:
    # Using the 'kite' session initialized from algotestlive
    
    # 1. Fetch Quote & LTP to get instrument_token and current price
    instrument_key = f"{exchange}:{tradingsymbol}"
    print(f"\nFetching Data for {instrument_key}...")
    
    try:
        quote = kite.quote([instrument_key])
        if instrument_key in quote:
            ltp = quote[instrument_key]['last_price']
            instrument_token = quote[instrument_key]['instrument_token']
            print(f"> LTP: {ltp}, Token: {instrument_token}")
        else:
            print(f"⚠️ Could not fetch quote for {instrument_key}. Using fallback dummy values for testing logic.")
            ltp = 75000.0
            instrument_token = 250000 
    except Exception as e:
        print(f"Error fetching quote: {e}")
        ltp = 75000.0
        instrument_token = 250000

    product_type = kite.PRODUCT_NRML

    # 2. Test Market Orders (BUY & SELL)
    print("\n--- Testing Market Orders ---")
    place_market_order(kite, tradingsymbol, exchange, kite.TRANSACTION_TYPE_BUY, quantity, product_type)
    place_market_order(kite, tradingsymbol, exchange, kite.TRANSACTION_TYPE_SELL, quantity, product_type)

    # 3. Test Limit Orders (BUY below LTP, SELL above LTP)
    print("\n--- Testing Limit Orders ---")
    buy_limit_price = round(ltp * 0.98, 1)  # 2% below LTP
    sell_limit_price = round(ltp * 1.02, 1) # 2% above LTP
    place_limit_order(kite, tradingsymbol, exchange, kite.TRANSACTION_TYPE_BUY, quantity, buy_limit_price, product_type)
    place_limit_order(kite, tradingsymbol, exchange, kite.TRANSACTION_TYPE_SELL, quantity, sell_limit_price, product_type)

    # 4. Test GTT Stoplosses at multiple offsets
    print("\n--- Testing Multiple GTT Offsets ---")
    import time
    offsets = [0.1, 0.2, -0.1, -0.2]
    for off in offsets:
        print(f"\n>> Initiating GTT at {off}% offset:")
        place_stop_loss_gtt(kite, tradingsymbol, exchange, trigger_percent=off, quantity=quantity, product=product_type)
        time.sleep(0.5)

    # 5. Test Alerts
    print("\n--- Testing Sentinel/Alerts API ---")
    # Alert if price drops 1%
    trigger_price = round(ltp * 0.99, 1)
    create_alert(
        kite=kite, 
        name=f"TestAlert_{tradingsymbol}", 
        instrument_token=instrument_token, 
        operator="<=", 
        trigger_price=trigger_price
    )
    
else:
    print("❌ kite is not defined or initialized. Run the Session Initialization cell first.")
# Out:
# ...
# 🧪 Testing Full Suite on algotestlive
# ...
#
# Fetching Data for MCX:GOLDM26APRFUT...
# > LTP: 142177, Token: 122343431
#
# --- Testing Market Orders ---
# ❌ Error placing market order: MCX is disabled for your account. You can activate the segment on [Console.](https://console.zerodha.com/account/segment-activation)
# ❌ Error placing market order: MCX is disabled for your account. You can activate the segment on [Console.](https://console.zerodha.com/account/segment-activation)
#
# --- Testing Limit Orders ---
# ❌ Error placing limit order: MCX is disabled for your account. You can activate the segment on [Console.](https://console.zerodha.com/account/segment-activation)
# ❌ Error placing limit order: MCX is disabled for your account. You can activate the segment on [Console.](https://console.zerodha.com/account/segment-activation)
#
# --- Testing Multiple GTT Offsets ---
#
# >> Initiating GTT at 0.1% offset:
# Current LTP for GOLDM26APRFUT: 142177
# ...

# %%
# --- Dynamic Instrument Search and GTT Test ---
print("=====================================")
print("🧪 Testing GTTs on 142000 CE and PE")
print("=====================================")

# 1. Search for exactly MARCH 142000 CE and PE in MCX
print("Fetching MCX instruments list... this might take a second.")
if 'kite' in locals() and kite:
    instruments = kite.instruments(exchange='MCX')

    ce_symbol = None
    pe_symbol = None

    for i in instruments:
        name = i['tradingsymbol']
        if 'GOLDM' in name and '142000' in name and 'MAR' in name:
            if name.endswith('CE'):
                ce_symbol = name
            elif name.endswith('PE'):
                pe_symbol = name

    if not ce_symbol or not pe_symbol:
        print("❌ Could not find BOTH matching 142000 CE and PE instruments for MAR on MCX!")
        print(f"Found CE: {ce_symbol}")
        print(f"Found PE: {pe_symbol}")
    else:
        print(f"✅ Found CE: {ce_symbol}")
        print(f"✅ Found PE: {pe_symbol}")
        
        # 2. Test Multiple GTTs on both
        import time
        offsets = [0.1, 0.2, -0.1, -0.2]
        
        for symbol in [ce_symbol, pe_symbol]:
            print(f"\n=====================================")
            print(f"Executing GTT Suite for {symbol}")
            print(f"=====================================")
            
            product_type = kite.PRODUCT_NRML
            
            for off in offsets:
                print(f"\n>> Placing GTT for {symbol} at {off}% offset:")
                # Because place_stop_loss_gtt has proactive 0.25% validation, we can safely pass low values!
                place_stop_loss_gtt(kite, symbol, "MCX", trigger_percent=off, quantity=1, product=product_type)
                time.sleep(0.5)
else:
    print("❌ kite is not defined! Run the Session Initialization cell first.")
# Out:
# ...
# 🧪 Testing GTTs on 142000 CE and PE
# ...
# Fetching MCX instruments list... this might take a second.
# ✅ Found CE: GOLDM26MAR142000CE
# ✅ Found PE: GOLDM26MAR142000PE
#
# ...
# Executing GTT Suite for GOLDM26MAR142000CE
# ...
#
# >> Placing GTT for GOLDM26MAR142000CE at 0.1% offset:
# Current LTP for GOLDM26MAR142000CE: 537.5
# ⚠️ Warning: 0.1% is too close to LTP. Kite requires >0.25% gap.
# 🔄 Auto-adjusting trigger_percent from 0.1% to 0.26%
# Calculated SL Trigger Price (0.26% drop): 536.1
# ✅ GTT Order Placed. ID: {'trigger_id': 312862659}
#
# >> Placing GTT for GOLDM26MAR142000CE at 0.2% offset:
# Current LTP for GOLDM26MAR142000CE: 525
# ⚠️ Warning: 0.2% is too close to LTP. Kite requires >0.25% gap.
# 🔄 Auto-adjusting trigger_percent from 0.2% to 0.26%
# Calculated SL Trigger Price (0.26% drop): 523.65
# ✅ GTT Order Placed. ID: {'trigger_id': 312862661}
#
# >> Placing GTT for GOLDM26MAR142000CE at -0.1% offset:
# Current LTP for GOLDM26MAR142000CE: 525
# ...

# %%
# =============================================================
# 🧪 LIVE TEST: PriceMonitor + TSL with DB Persistence
# =============================================================
# DB-backed TSL tracking for GOLDM 142000 CE/PE on MCX.
# The `active_tsl_orders` table in trading_data.db is the single
# source of truth — survives overnight / kernel restarts.
# DRY-RUN mode (zero funds): no GTTs placed, all logic is live.
# =============================================================

import time
import sqlite3
import os
from datetime import datetime

# --- 0. Database Setup ---
DB_PATH = os.path.join(os.path.dirname(os.getcwd()), 'trading_data.db')
print(f"📂 Database: {DB_PATH}")

db = sqlite3.connect(DB_PATH)
db.row_factory = sqlite3.Row  # Dict-like access
cur = db.cursor()

# Create tables if they don't exist
cur.execute('''
    CREATE TABLE IF NOT EXISTS active_tsl_orders (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        symbol TEXT NOT NULL,
        exchange TEXT NOT NULL,
        quantity INTEGER NOT NULL DEFAULT 1,
        product TEXT DEFAULT 'NRML',
        trailing_percent REAL NOT NULL,
        hwm_price REAL NOT NULL,
        last_trigger_price REAL DEFAULT 0,
        gtt_id INTEGER,
        status TEXT NOT NULL DEFAULT 'active',
        created_at DATETIME DEFAULT CURRENT_TIMESTAMP,
        updated_at DATETIME DEFAULT CURRENT_TIMESTAMP
    )
''')

cur.execute('''
    CREATE TABLE IF NOT EXISTS price_monitor_log (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        symbol TEXT NOT NULL,
        exchange TEXT NOT NULL,
        ltp REAL NOT NULL,
        hwm_price REAL,
        trailing_sl_price REAL,
        trailing_percent REAL,
        logged_at DATETIME DEFAULT CURRENT_TIMESTAMP
    )
''')
db.commit()
print("✅ Tables ready (active_tsl_orders, price_monitor_log)")

# --- 1. Resume or Create TSL Entries ---
EXCHANGE = 'MCX'
STRIKE = '142000'
TRAILING_PCT = 3.0
QUANTITY = 1
PRODUCT = 'NRML'

# Check for existing active orders in DB
cur.execute(
    "SELECT * FROM active_tsl_orders WHERE status = 'active' AND symbol LIKE ? AND exchange = ?",
    (f'%GOLDM%{STRIKE}%', EXCHANGE)
)
existing_orders = cur.fetchall()

if existing_orders:
    # --- RESUME from DB (overnight recovery!) ---
    print(f"\n🔄 RESUMING {len(existing_orders)} active TSL order(s) from database:")
    tracked_positions = []
    for row in existing_orders:
        print(f"  📌 {row['symbol']} | HWM: {row['hwm_price']} | SL: {row['last_trigger_price']} | GTT: {row['gtt_id']}")
        tracked_positions.append({
            'db_id': row['id'],
            'symbol': row['symbol'],
            'exchange': row['exchange'],
            'quantity': row['quantity'],
            'product': row['product'],
            'percent': row['trailing_percent'],
            'hwm_price': row['hwm_price'],
            'last_trigger_price': row['last_trigger_price'],
            'gtt_id': row['gtt_id']
        })
else:
    # --- CREATE new entries ---
    print(f"\n🔍 No active TSL orders found. Searching for GOLDM {STRIKE} CE/PE on {EXCHANGE}...")
    instruments = kite.instruments(exchange=EXCHANGE)
    
    ce_symbol = None
    pe_symbol = None
    for inst in instruments:
        name = inst['tradingsymbol']
        if 'GOLDM' in name and STRIKE in name:
            if name.endswith('CE') and ce_symbol is None:
                ce_symbol = name
            elif name.endswith('PE') and pe_symbol is None:
                pe_symbol = name
    
    found_symbols = [s for s in [ce_symbol, pe_symbol] if s]
    if not found_symbols:
        print(f"❌ Could not find GOLDM {STRIKE} CE or PE. Is the contract live?")
        db.close()
        raise SystemExit
    
    # Fetch initial LTP for each symbol to set starting HWM
    tracked_positions = []
    for sym in found_symbols:
        key = f"{EXCHANGE}:{sym}"
        try:
            ltp_data = kite.ltp(key)
            initial_price = ltp_data[key]['last_price']
        except Exception as e:
            print(f"  ⚠️ Could not fetch LTP for {sym}: {e}")
            initial_price = 0
        
        # Insert into DB
        cur.execute(
            '''INSERT INTO active_tsl_orders 
               (symbol, exchange, quantity, product, trailing_percent, hwm_price, last_trigger_price, status)
               VALUES (?, ?, ?, ?, ?, ?, 0, 'active')''',
            (sym, EXCHANGE, QUANTITY, PRODUCT, TRAILING_PCT, initial_price)
        )
        db_id = cur.lastrowid
        db.commit()
        
        print(f"  ✅ Created: {sym} | Initial HWM: {initial_price} | DB ID: {db_id}")
        tracked_positions.append({
            'db_id': db_id,
            'symbol': sym,
            'exchange': EXCHANGE,
            'quantity': QUANTITY,
            'product': PRODUCT,
            'percent': TRAILING_PCT,
            'hwm_price': initial_price,
            'last_trigger_price': 0,
            'gtt_id': None
        })

# --- 2. Initialize PriceMonitor ---
monitor = PriceMonitor(kite)
for pos in tracked_positions:
    monitor.add_symbol(pos['exchange'], pos['symbol'])

# --- 3. Monitoring Loop ---
NUM_TICKS = 3
INTERVAL = 2  # seconds

print(f"\n{'='*60}")
print(f"🚀 Starting TSL Monitor ({NUM_TICKS} ticks, {INTERVAL}s interval)")
print(f"{'='*60}")

for tick in range(NUM_TICKS):
    ts = datetime.now().strftime('%H:%M:%S')
    print(f"\n--- Tick {tick+1}/{NUM_TICKS} @ {ts} ---")
    
    # Fetch fresh prices
    monitor.update_prices()
    
    for pos in tracked_positions:
        sym = pos['symbol']
        exch = pos['exchange']
        trail_pct = pos['percent']
        
        price = monitor.get_price(exch, sym)
        if price is None:
            print(f"  ⚠️ {sym}: No price")
            continue
        
        old_hwm = pos['hwm_price']
        
        # Update HWM if price went higher
        if price > old_hwm:
            pos['hwm_price'] = price
            print(f"  🚀 {sym}: NEW HWM! {old_hwm} → {price}")
        else:
            print(f"  📈 {sym}: LTP={price} (HWM={old_hwm}, unchanged)")
        
        hwm = pos['hwm_price']
        
        # Calculate trailing SL from HWM
        new_sl = round(hwm * (1 - trail_pct / 100) * 20) / 20  # tick-rounded
        old_sl = pos['last_trigger_price']
        
        if new_sl > old_sl:
            pos['last_trigger_price'] = new_sl
            print(f"  ⚡ SL trailed up: {old_sl} → {new_sl}")
        
        print(f"  🎯 TSL: HWM={hwm} | SL@{trail_pct}%={new_sl}")
        
        # --- DRY RUN NOTE ---
        # When funds are available, uncomment to place/modify real GTTs:
        # tsl_manager.update_trailing_stop_loss(
        #     tradingsymbol=sym, exchange=exch,
        #     trailing_percent=trail_pct, quantity=pos['quantity'],
        #     product=pos['product'], gtt_id=pos['gtt_id'],
        #     current_ltp=price
        # )
        
        # Persist to DB — active_tsl_orders
        cur.execute(
            '''UPDATE active_tsl_orders 
               SET hwm_price = ?, last_trigger_price = ?, updated_at = CURRENT_TIMESTAMP
               WHERE id = ?''',
            (pos['hwm_price'], pos['last_trigger_price'], pos['db_id'])
        )
        
        # Log tick to price_monitor_log
        cur.execute(
            '''INSERT INTO price_monitor_log 
               (symbol, exchange, ltp, hwm_price, trailing_sl_price, trailing_percent)
               VALUES (?, ?, ?, ?, ?, ?)''',
            (sym, exch, price, pos['hwm_price'], new_sl, trail_pct)
        )
    
    db.commit()
    
    if tick < NUM_TICKS - 1:
        time.sleep(INTERVAL)

# --- 4. Summary ---
print(f"\n{'='*60}")
print("📊 Test Complete!")
print(f"{'='*60}")

# Active TSL Orders from DB
print("\n🗂️ Active TSL Orders (from DB):")
cur.execute("SELECT id, symbol, hwm_price, last_trigger_price, gtt_id, status, updated_at FROM active_tsl_orders WHERE status = 'active'")
for row in cur.fetchall():
    print(f"  [{row['id']}] {row['symbol']}  HWM={row['hwm_price']}  SL={row['last_trigger_price']}  GTT={row['gtt_id']}  ({row['status']})  updated: {row['updated_at']}")

# Recent price logs
print("\n📋 Recent Price Log:")
cur.execute("SELECT symbol, ltp, hwm_price, trailing_sl_price, logged_at FROM price_monitor_log ORDER BY id DESC LIMIT 6")
rows = cur.fetchall()
print(f"  {'Symbol':<30} {'LTP':>8} {'HWM':>8} {'SL':>8}  Time")
print(f"  {'-'*75}")
for r in rows:
    print(f"  {r['symbol']:<30} {r['ltp']:>8.2f} {r['hwm_price']:>8.2f} {r['trailing_sl_price']:>8.2f}  {r['logged_at']}")

cur.execute("SELECT COUNT(*) as cnt FROM price_monitor_log")
print(f"\n💾 Total price log entries: {cur.fetchone()['cnt']}")

db.close()
print("\n✅ Done! DB saved & closed. Re-run this cell to test overnight resume.")
